# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# - Không có năm nào mà có nhiều hơn 1 quốc gia đồng tổ chức olympic
# -

# %%
data = pd.read_csv('./olympic_athletes_data.csv')

# %%
data.head()
# Out:
#         Athlete Name       Host City Host Country  Year Athlete Team Country  \
# 0  Foluke Akinradewo  Rio de Janeiro       Brazil  2016                  USA
# 1         Lucy Davis  Rio de Janeiro       Brazil  2016                  USA
# 2        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 3        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 4        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
#
#                 Sport                  Event   Medal
# 0  Women's Volleyball                 Indoor  Bronze
# 1          Equestrian      Team Show Jumping  Silver
# 2    Women's Swimming         200 Backstroke    Gold
# 3    Women's Swimming    800 Freestyle Relay    Gold
# 4    Women's Swimming  400 Individual Medley  Silver

# %%
data.drop(np.where(data['Athlete Team Country'] != 'USA')[0], inplace=True)

# %%
data.head()
# Out:
#         Athlete Name       Host City Host Country  Year Athlete Team Country  \
# 0  Foluke Akinradewo  Rio de Janeiro       Brazil  2016                  USA
# 1         Lucy Davis  Rio de Janeiro       Brazil  2016                  USA
# 2        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 3        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 4        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
#
#                 Sport                  Event   Medal
# 0  Women's Volleyball                 Indoor  Bronze
# 1          Equestrian      Team Show Jumping  Silver
# 2    Women's Swimming         200 Backstroke    Gold
# 3    Women's Swimming    800 Freestyle Relay    Gold
# 4    Women's Swimming  400 Individual Medley  Silver

# %%
data.describe()
# Out:
#               Year
# count   264.000000
# mean   1978.484848
# std      32.453180
# min    1912.000000
# 25%    1959.000000
# 50%    1992.000000
# 75%    2008.000000
# max    2016.000000

# %%
data.loc[data['Medal'] == 'Bronze (tie)', 'Medal'] = 'Bronze'

# %%
data.groupby('Medal').count()
# Out:
#         Athlete Name  Host City  Host Country  Year  Athlete Team Country  \
# Medal
# Bronze            56         56            56    56                    56
# Gold             137        137           137   137                   137
# Silver            71         71            71    71                    71
#
#         Sport  Event
# Medal
# Bronze     56     56
# Gold      137    137
# Silver     71     71

# %%
medal = pd.get_dummies(data['Medal'])
medal
# Out:
#      Bronze  Gold  Silver
# 0         1     0       0
# 1         0     0       1
# 2         0     1       0
# 3         0     1       0
# 4         0     0       1
# ..      ...   ...     ...
# 265       0     1       0
# 266       0     1       0
# 267       0     1       0
# 268       0     1       0
# 269       1     0       0
#
# [264 rows x 3 columns]

# %%
data = pd.concat([data, medal], axis=1)

# %%
data.head()
# Out:
#         Athlete Name       Host City Host Country  Year Athlete Team Country  \
# 0  Foluke Akinradewo  Rio de Janeiro       Brazil  2016                  USA
# 1         Lucy Davis  Rio de Janeiro       Brazil  2016                  USA
# 2        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 3        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 4        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
#
#                 Sport                  Event   Medal  Bronze  Gold  Silver
# 0  Women's Volleyball                 Indoor  Bronze       1     0       0
# 1          Equestrian      Team Show Jumping  Silver       0     0       1
# 2    Women's Swimming         200 Backstroke    Gold       0     1       0
# 3    Women's Swimming    800 Freestyle Relay    Gold       0     1       0
# 4    Women's Swimming  400 Individual Medley  Silver       0     0       1

# %%
data.drop(['Medal'], axis = 1, inplace=True)

# %%
data.head()
# Out:
#         Athlete Name       Host City Host Country  Year Athlete Team Country  \
# 0  Foluke Akinradewo  Rio de Janeiro       Brazil  2016                  USA
# 1         Lucy Davis  Rio de Janeiro       Brazil  2016                  USA
# 2        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 3        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
# 4        Maya DiRado  Rio de Janeiro       Brazil  2016                  USA
#
#                 Sport                  Event  Bronze  Gold  Silver
# 0  Women's Volleyball                 Indoor       1     0       0
# 1          Equestrian      Team Show Jumping       0     0       1
# 2    Women's Swimming         200 Backstroke       0     1       0
# 3    Women's Swimming    800 Freestyle Relay       0     1       0
# 4    Women's Swimming  400 Individual Medley       0     0       1

# %%
sport = data.loc[:, ['Sport', 'Bronze', 'Gold', 'Silver']].groupby('Sport').count()
sport.head()
# Out:
#                   Bronze  Gold  Silver
# Sport
# Baseball               2     2       2
# Equestrian             1     1       1
# Field Hockey           1     1       1
# Men's Basketball       2     2       2
# Men's Diving          11    11      11

# %%
sport.index
# Out:
# 'Baseball'

# %%
plt.bar(sport.index, sport['Bronze'], label='B')
plt.bar(sport.index, sport['Gold'])
plt.bar(sport.index, sport['Silver'])
# Out:
# <BarContainer object of 29 artists>
